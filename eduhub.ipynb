# %%
# === Part 1: Database Setup and Data Modeling ===

## Step 1.1: Connect to MongoDB and Create Database
#loading neccessary libraries and dependencies
from pymongo import MongoClient
from datetime import datetime, timedelta
import pandas as pd
import random

# Connect to local MongoDB server
client = MongoClient('mongodb://localhost:27017/')

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'cooker', 'db', 'eduhub_db', 'local', 'test']

# %%
# Createing database (6)
eduhub_db = client['eduhub_db']

## Step 1.2: Define Collections
users_collection = eduhub_db['users']
courses_collection = eduhub_db['courses']
enrollments_collection = eduhub_db['enrollments']
lessons_collection = eduhub_db['lessons']
assignments_collection = eduhub_db['assignments']
submissions_collection = eduhub_db['submissions']

# %% [markdown]
# # Generating Sample data

# %%
user_sample = {
    # MongoDB automatically generates "_id"
    "userId": "U001",
    "email": "john.doe@example.com",
    "firstName": "John",
    "lastName": "Doe",
    "role": "student",  # or "instructor"
    "dateJoined": datetime.utcnow(),
    "profile": {
        "bio": "Aspiring data analyst.",
        "avatar": "https://example.com/avatar/john.jpg",
        "skills": ["Python", "SQL", "Excel"]
    },
    "isActive": True
}

# %%
course_sample = {
    # "_id" is auto-generated by MongoDB
    "courseId": "C101",  
    "title": "Intro to Python",  
    "description": "A hands-on course for beginners learning Python.",
    "instructorId": "U002",  
    "category": "Programming",
    "level": "beginner",  
    "duration": 15,  
    "price": 49.99, 
    "tags": ["python", "coding", "beginner"],
    "createdAt": datetime.utcnow(),
    "updatedAt": datetime.utcnow(),
    "isPublished": True
}

# %%
enrollment_sample = {
    "enrollmentId": "E001",
    "userId": "U001",       
    "courseId": "C101",      
    "enrolledAt": datetime.utcnow(),
    "progress": 20          
}

# %%
lesson_sample = {
    "lessonId": "L001",
    "courseId": "C101",     
    "title": "Getting Started with Python",
    "content": "Text, links, or video URL for the lesson.",
    "duration": 30,      
    "order": 1              
}

# %%
assignment_sample = {
    "assignmentId": "A001",          
    "courseId": "C101",               
    "title": "Python Basics Quiz", 
    "description": "Test your understanding of basic Python concepts.",
    "dueDate": datetime.utcnow(), 
    "maxScore": 100,    
    "createdAt": datetime.utcnow(), 
    "updatedAt": datetime.utcnow(), 
    "type": "quiz",        
    "resources": [                   
        "https://docs.python.org/3/tutorial/",
        "https://realpython.com/"
    ]
}

# %%
submission_sample = {
    "submissionId": "S001",
    "assignmentId": "A001", 
    "userId": "U001",    
    "submittedAt": datetime.utcnow(),
    "grade": 85,   
    "feedback": "Nice work! Keep going!"
}

# %% [markdown]
# ## Inserting Sample Data into the Data
# ---
# 1. users.json – 20 users
#
# 2. courses.json – 8 courses
#
# 3. enrollments.json – 15 enrollments
#
# 4. lessons.json – 25 lessons
#
# 5. assignments.json – 10 assignments
#
# 6. submissions.json – 12 assignment submissions
#
# This data was a json file used to populate the model

# %%
#importing json library to load the json file
import json
#loading the users data
with open("Data/users.json", "r") as file:
    users_data = json.load(file)
    eduhub_db.users.insert_many(users_data)
    print(f'There are {len(users_data)} data loaded')
# Out:
# There are 20 data loaded

# %%
#loading the courses data
with open("Data/courses.json", "r") as file:
    course_data = json.load(file)
    eduhub_db.courses.insert_many(course_data)
    print(f'There are {len(course_data)} data loaded')
# Out:
# There are 8 data loaded

# %%
#loading the enrollments data
with open("Data/enrollments.json", "r") as file:
    enrollments_data = json.load(file)
    eduhub_db.enrollments.insert_many(enrollments_data)
    print(f'There are {len(enrollments_data)} data loaded')
# Out:
# There are 15 data loaded

# %%
#loading the lessons data
with open("Data/lessons.json", "r") as file:
    lessons_data = json.load(file)
    eduhub_db.lessons.insert_many(lessons_data)
    print(f'There are {len(lessons_data)} data loaded')
# Out:
# There are 25 data loaded

# %%
#loading the assignments data
with open("Data/assignments.json", "r") as file:
    assignments_data = json.load(file)
    eduhub_db.assignments.insert_many(assignments_data)
    print(f'There are {len(assignments_data)} data loaded')
# Out:
# There are 10 data loaded

# %%
#loading the submissions data
with open("Data/submissions.json", "r") as file:
    submissions_data = json.load(file)
    eduhub_db.submissions.insert_many(submissions_data)
    print(f'There are {len(submissions_data)} data loaded')
# Out:
# There are 12 data loaded

# %%
# Get all instructor userIds
instructors = {user["userId"] for user in eduhub_db.users.find({"role": "instructor"})}
print(instructors)
# Out:
# {'U006', 'U001', 'U016', 'U011'}

# %% [markdown]
# ## Part 3: Basic CRUD Operations (25 points)
# ###
# Task 3.1: Create Operations
# Write Python code using PyMongo to:
#
# Add a new student user
# Create a new course
# Enroll a student in a course
# Add a new lesson to an existing course

# %%
# adding a new student
new_user = {
    "user_id": "U1001",
    "name": "Jane Smith",
    "email": "jane.smith@example.com",
    "role": "student",
    "created_at": "2025-06-17T00:00:00Z"
}

result = users_collection.insert_one(new_user)
print(f"Inserted user with _id: {result.inserted_id}")
# Out:
# Inserted user with _id: 6850ed382f50a96332a45afd

# %%
#creating new course
new_course = {
    "course_id": "C2001",
    "title": "Python for Beginners",
    "description": "An introductory Python course.",
    "category": "Programming",
    "level": "beginner",
    "duration": 8,
    "price": 30.0,
    "instructor_id": "U001",  # Example instructor ID
    "created_at": "2025-06-17T00:00:00Z"
}

result = courses_collection.insert_one(new_course)
print(f"Inserted course with _id: {result.inserted_id}")
# Out:
# Inserted course with _id: 6850ed662f50a96332a45afe

# %%
#enroll a student in a course
new_enrollment = {
    "user_id": "U1001",
    "course_id": "C2001",
    "enrolled_at": "2025-06-17T00:00:00Z"
}

result = enrollments_collection.insert_one(new_enrollment)
print(f"Inserted enrollment with _id: {result.inserted_id}")
# Out:
# Inserted enrollment with _id: 6850ed7b2f50a96332a45aff

# %%
#adding a new lesson to an existing
new_lesson = {
    "lesson_id": "L3001",
    "course_id": "C2001",
    "title": "Lesson 1: Getting Started",
    "content": "Welcome to Python! In this lesson, we'll cover basics.",
    "created_at": "2025-06-17T00:00:00Z"
}

result = lessons_collection.insert_one(new_lesson)
print(f"Inserted lesson with _id: {result.inserted_id}")
# Out:
# Inserted lesson with _id: 6850ed9a2f50a96332a45b00

# %%
# find active student
active_students = users_collection.find({"role": "student"})

for student in active_students:
    print(student)
# Out:
# {'_id': ObjectId('6850e0b52d219fdf68002517'), 'userId': 'U002', 'email': 'user2@example.com', 'firstName': 'First2', 'lastName': 'Last2', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002518'), 'userId': 'U003', 'email': 'user3@example.com', 'firstName': 'First3', 'lastName': 'Last3', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002519'), 'userId': 'U004', 'email': 'user4@example.com', 'firstName': 'First4', 'lastName': 'Last4', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf6800251a'), 'userId': 'U005', 'email': 'user5@example.com', 'firstName': 'First5', 'lastName': 'Last5', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf6800251c'), 'userId': 'U007', 'email': 'user7@example.com', 'firstName': 'First7', 'lastName': 'Last7', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf6800251d'), 'userId': 'U008', 'email': 'user8@example.com', 'firstName': 'First8', 'lastName': 'Last8', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf6800251e'), 'userId': 'U009', 'email': 'user9@example.com', 'firstName': 'First9', 'lastName': 'Last9', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf6800251f'), 'userId': 'U010', 'email': 'user10@example.com', 'firstName': 'First10', 'lastName': 'Last10', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002521'), 'userId': 'U012', 'email': 'user12@example.com', 'firstName': 'First12', 'lastName': 'Last12', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002522'), 'userId': 'U013', 'email': 'user13@example.com', 'firstName': 'First13', 'lastName': 'Last13', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002523'), 'userId': 'U014', 'email': 'user14@example.com', 'firstName': 'First14', 'lastName': 'Last14', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002524'), 'userId': 'U015', 'email': 'user15@example.com', 'firstName': 'First15', 'lastName': 'Last15', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002526'), 'userId': 'U017', 'email': 'user17@example.com', 'firstName': 'First17', 'lastName': 'Last17', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002527'), 'userId': 'U018', 'email': 'user18@example.com', 'firstName': 'First18', 'lastName': 'Last18', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002528'), 'userId': 'U019', 'email': 'user19@example.com', 'firstName': 'First19', 'lastName': 'Last19', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0b52d219fdf68002529'), 'userId': 'U020', 'email': 'user20@example.com', 'firstName': 'First20', 'lastName': 'Last20', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800252b'), 'userId': 'U002', 'email': 'user2@example.com', 'firstName': 'First2', 'lastName': 'Last2', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800252c'), 'userId': 'U003', 'email': 'user3@example.com', 'firstName': 'First3', 'lastName': 'Last3', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800252d'), 'userId': 'U004', 'email': 'user4@example.com', 'firstName': 'First4', 'lastName': 'Last4', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800252e'), 'userId': 'U005', 'email': 'user5@example.com', 'firstName': 'First5', 'lastName': 'Last5', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002530'), 'userId': 'U007', 'email': 'user7@example.com', 'firstName': 'First7', 'lastName': 'Last7', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002531'), 'userId': 'U008', 'email': 'user8@example.com', 'firstName': 'First8', 'lastName': 'Last8', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002532'), 'userId': 'U009', 'email': 'user9@example.com', 'firstName': 'First9', 'lastName': 'Last9', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002533'), 'userId': 'U010', 'email': 'user10@example.com', 'firstName': 'First10', 'lastName': 'Last10', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002535'), 'userId': 'U012', 'email': 'user12@example.com', 'firstName': 'First12', 'lastName': 'Last12', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002536'), 'userId': 'U013', 'email': 'user13@example.com', 'firstName': 'First13', 'lastName': 'Last13', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002537'), 'userId': 'U014', 'email': 'user14@example.com', 'firstName': 'First14', 'lastName': 'Last14', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf68002538'), 'userId': 'U015', 'email': 'user15@example.com', 'firstName': 'First15', 'lastName': 'Last15', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800253a'), 'userId': 'U017', 'email': 'user17@example.com', 'firstName': 'First17', 'lastName': 'Last17', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800253b'), 'userId': 'U018', 'email': 'user18@example.com', 'firstName': 'First18', 'lastName': 'Last18', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800253c'), 'userId': 'U019', 'email': 'user19@example.com', 'firstName': 'First19', 'lastName': 'Last19', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e0c02d219fdf6800253d'), 'userId': 'U020', 'email': 'user20@example.com', 'firstName': 'First20', 'lastName': 'Last20', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025a3'), 'userId': 'U002', 'email': 'user2@example.com', 'firstName': 'First2', 'lastName': 'Last2', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025a4'), 'userId': 'U003', 'email': 'user3@example.com', 'firstName': 'First3', 'lastName': 'Last3', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025a5'), 'userId': 'U004', 'email': 'user4@example.com', 'firstName': 'First4', 'lastName': 'Last4', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025a6'), 'userId': 'U005', 'email': 'user5@example.com', 'firstName': 'First5', 'lastName': 'Last5', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025a8'), 'userId': 'U007', 'email': 'user7@example.com', 'firstName': 'First7', 'lastName': 'Last7', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025a9'), 'userId': 'U008', 'email': 'user8@example.com', 'firstName': 'First8', 'lastName': 'Last8', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025aa'), 'userId': 'U009', 'email': 'user9@example.com', 'firstName': 'First9', 'lastName': 'Last9', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025ab'), 'userId': 'U010', 'email': 'user10@example.com', 'firstName': 'First10', 'lastName': 'Last10', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025ad'), 'userId': 'U012', 'email': 'user12@example.com', 'firstName': 'First12', 'lastName': 'Last12', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025ae'), 'userId': 'U013', 'email': 'user13@example.com', 'firstName': 'First13', 'lastName': 'Last13', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025af'), 'userId': 'U014', 'email': 'user14@example.com', 'firstName': 'First14', 'lastName': 'Last14', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025b0'), 'userId': 'U015', 'email': 'user15@example.com', 'firstName': 'First15', 'lastName': 'Last15', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025b2'), 'userId': 'U017', 'email': 'user17@example.com', 'firstName': 'First17', 'lastName': 'Last17', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025b3'), 'userId': 'U018', 'email': 'user18@example.com', 'firstName': 'First18', 'lastName': 'Last18', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025b4'), 'userId': 'U019', 'email': 'user19@example.com', 'firstName': 'First19', 'lastName': 'Last19', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850e9ab2d219fdf680025b5'), 'userId': 'U020', 'email': 'user20@example.com', 'firstName': 'First20', 'lastName': 'Last20', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4d5'), 'userId': 'U002', 'email': 'user2@example.com', 'firstName': 'First2', 'lastName': 'Last2', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4d6'), 'userId': 'U003', 'email': 'user3@example.com', 'firstName': 'First3', 'lastName': 'Last3', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4d7'), 'userId': 'U004', 'email': 'user4@example.com', 'firstName': 'First4', 'lastName': 'Last4', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4d8'), 'userId': 'U005', 'email': 'user5@example.com', 'firstName': 'First5', 'lastName': 'Last5', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4da'), 'userId': 'U007', 'email': 'user7@example.com', 'firstName': 'First7', 'lastName': 'Last7', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4db'), 'userId': 'U008', 'email': 'user8@example.com', 'firstName': 'First8', 'lastName': 'Last8', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4dc'), 'userId': 'U009', 'email': 'user9@example.com', 'firstName': 'First9', 'lastName': 'Last9', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4dd'), 'userId': 'U010', 'email': 'user10@example.com', 'firstName': 'First10', 'lastName': 'Last10', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4df'), 'userId': 'U012', 'email': 'user12@example.com', 'firstName': 'First12', 'lastName': 'Last12', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e0'), 'userId': 'U013', 'email': 'user13@example.com', 'firstName': 'First13', 'lastName': 'Last13', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e1'), 'userId': 'U014', 'email': 'user14@example.com', 'firstName': 'First14', 'lastName': 'Last14', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e2'), 'userId': 'U015', 'email': 'user15@example.com', 'firstName': 'First15', 'lastName': 'Last15', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e4'), 'userId': 'U017', 'email': 'user17@example.com', 'firstName': 'First17', 'lastName': 'Last17', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e5'), 'userId': 'U018', 'email': 'user18@example.com', 'firstName': 'First18', 'lastName': 'Last18', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e6'), 'userId': 'U019', 'email': 'user19@example.com', 'firstName': 'First19', 'lastName': 'Last19', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850ea1c4e711552609ea4e7'), 'userId': 'U020', 'email': 'user20@example.com', 'firstName': 'First20', 'lastName': 'Last20', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a90'), 'userId': 'U002', 'email': 'user2@example.com', 'firstName': 'First2', 'lastName': 'Last2', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a91'), 'userId': 'U003', 'email': 'user3@example.com', 'firstName': 'First3', 'lastName': 'Last3', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a92'), 'userId': 'U004', 'email': 'user4@example.com', 'firstName': 'First4', 'lastName': 'Last4', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a93'), 'userId': 'U005', 'email': 'user5@example.com', 'firstName': 'First5', 'lastName': 'Last5', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a95'), 'userId': 'U007', 'email': 'user7@example.com', 'firstName': 'First7', 'lastName': 'Last7', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a96'), 'userId': 'U008', 'email': 'user8@example.com', 'firstName': 'First8', 'lastName': 'Last8', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a97'), 'userId': 'U009', 'email': 'user9@example.com', 'firstName': 'First9', 'lastName': 'Last9', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a98'), 'userId': 'U010', 'email': 'user10@example.com', 'firstName': 'First10', 'lastName': 'Last10', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a9a'), 'userId': 'U012', 'email': 'user12@example.com', 'firstName': 'First12', 'lastName': 'Last12', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a9b'), 'userId': 'U013', 'email': 'user13@example.com', 'firstName': 'First13', 'lastName': 'Last13', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a9c'), 'userId': 'U014', 'email': 'user14@example.com', 'firstName': 'First14', 'lastName': 'Last14', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a9d'), 'userId': 'U015', 'email': 'user15@example.com', 'firstName': 'First15', 'lastName': 'Last15', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45a9f'), 'userId': 'U017', 'email': 'user17@example.com', 'firstName': 'First17', 'lastName': 'Last17', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45aa0'), 'userId': 'U018', 'email': 'user18@example.com', 'firstName': 'First18', 'lastName': 'Last18', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45aa1'), 'userId': 'U019', 'email': 'user19@example.com', 'firstName': 'First19', 'lastName': 'Last19', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eaf12f50a96332a45aa2'), 'userId': 'U020', 'email': 'user20@example.com', 'firstName': 'First20', 'lastName': 'Last20', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aa4'), 'userId': 'U002', 'email': 'user2@example.com', 'firstName': 'First2', 'lastName': 'Last2', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aa5'), 'userId': 'U003', 'email': 'user3@example.com', 'firstName': 'First3', 'lastName': 'Last3', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aa6'), 'userId': 'U004', 'email': 'user4@example.com', 'firstName': 'First4', 'lastName': 'Last4', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aa7'), 'userId': 'U005', 'email': 'user5@example.com', 'firstName': 'First5', 'lastName': 'Last5', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aa9'), 'userId': 'U007', 'email': 'user7@example.com', 'firstName': 'First7', 'lastName': 'Last7', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aaa'), 'userId': 'U008', 'email': 'user8@example.com', 'firstName': 'First8', 'lastName': 'Last8', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aab'), 'userId': 'U009', 'email': 'user9@example.com', 'firstName': 'First9', 'lastName': 'Last9', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aac'), 'userId': 'U010', 'email': 'user10@example.com', 'firstName': 'First10', 'lastName': 'Last10', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aae'), 'userId': 'U012', 'email': 'user12@example.com', 'firstName': 'First12', 'lastName': 'Last12', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45aaf'), 'userId': 'U013', 'email': 'user13@example.com', 'firstName': 'First13', 'lastName': 'Last13', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45ab0'), 'userId': 'U014', 'email': 'user14@example.com', 'firstName': 'First14', 'lastName': 'Last14', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45ab1'), 'userId': 'U015', 'email': 'user15@example.com', 'firstName': 'First15', 'lastName': 'Last15', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45ab3'), 'userId': 'U017', 'email': 'user17@example.com', 'firstName': 'First17', 'lastName': 'Last17', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45ab4'), 'userId': 'U018', 'email': 'user18@example.com', 'firstName': 'First18', 'lastName': 'Last18', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45ab5'), 'userId': 'U019', 'email': 'user19@example.com', 'firstName': 'First19', 'lastName': 'Last19', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['Python', 'Excel']}, 'isActive': True}
# {'_id': ObjectId('6850eb7c2f50a96332a45ab6'), 'userId': 'U020', 'email': 'user20@example.com', 'firstName': 'First20', 'lastName': 'Last20', 'role': 'student', 'dateJoined': '2024-06-01T12:00:00Z', 'profile': {'bio': 'This is a sample bio.', 'avatar': '', 'skills': ['SQL', 'Power BI']}, 'isActive': True}
# {'_id': ObjectId('6850ed382f50a96332a45afd'), 'user_id': 'U1001', 'name': 'Jane Smith', 'email': 'jane.smith@example.com', 'role': 'student', 'created_at': '2025-06-17T00:00:00Z'}

# %%
get all courses with instructor details (simple version without aggregation)
instructors = users_collection.find({"role": "instructor"})
for instructor in instructors:
    print(f"Courses taught by {instructor['firstName']} {instructor['lastName']}:")
    instructor_courses = courses_collection.find({"instructorId": instructor["userId"]})
    for course in instructor_courses:
        print({
            "title": course["title"],
            "courseId": course["courseId"],
            "category": course["category"],
            "level": course["level"],
            "students_enrolled": enrollments_collection.count_documents({"courseId": course["courseId"]})
        })
    print()
# Out:
# Courses taught by First1 Last1:
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
#
# Courses taught by First6 Last6:
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
#
# Courses taught by First11 Last11:
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
#
# Courses taught by First16 Last16:
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
#
# Courses taught by First1 Last1:
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
#
# Courses taught by First6 Last6:
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
#
# Courses taught by First11 Last11:
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
#
# Courses taught by First16 Last16:
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
#
# Courses taught by First1 Last1:
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
#
# Courses taught by First6 Last6:
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
#
# Courses taught by First11 Last11:
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
#
# Courses taught by First16 Last16:
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
#
# Courses taught by First1 Last1:
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
#
# Courses taught by First6 Last6:
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
#
# Courses taught by First11 Last11:
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
#
# Courses taught by First16 Last16:
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
#
# Courses taught by First1 Last1:
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
#
# Courses taught by First6 Last6:
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
#
# Courses taught by First11 Last11:
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
#
# Courses taught by First16 Last16:
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
#
# Courses taught by First1 Last1:
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 1', 'courseId': 'C101', 'category': 'Programming', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 5', 'courseId': 'C105', 'category': 'Programming', 'level': 'intermediate', 'students_enrolled': 8}
#
# Courses taught by First6 Last6:
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 2', 'courseId': 'C102', 'category': 'Business', 'level': 'intermediate', 'students_enrolled': 8}
# {'title': 'Course Title 6', 'courseId': 'C106', 'category': 'Business', 'level': 'advanced', 'students_enrolled': 8}
#
# Courses taught by First11 Last11:
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 3', 'courseId': 'C103', 'category': 'Data Science', 'level': 'advanced', 'students_enrolled': 8}
# {'title': 'Course Title 7', 'courseId': 'C107', 'category': 'Data Science', 'level': 'beginner', 'students_enrolled': 8}
#
# Courses taught by First16 Last16:
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
# {'title': 'Course Title 4', 'courseId': 'C104', 'category': 'Design', 'level': 'beginner', 'students_enrolled': 8}
# {'title': 'Course Title 8', 'courseId': 'C108', 'category': 'Design', 'level': 'intermediate', 'students_enrolled': 4}
